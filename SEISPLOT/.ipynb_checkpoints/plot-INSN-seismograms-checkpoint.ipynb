# %% [markdown]
#  Run the next box to disable auto-scrolling of large figures:

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# Run the next box to load some defaults:

# %%
# %reload_ext autoreload
# %autoreload 1
# %aimport INSN
# %matplotlib notebook

# %% [markdown]
# Specify date and time :

# %%
# Input the date and time of the event
Year =  2019; Month = 12; Day = 15
Hour = 21; Minute = 19; Second = 52.3

# %% [markdown]
# If you know the epicentre coordinates and hypocentral depth change them accordingly:

# %%
lat = 53.684
lon = -4.897
depth = 9  # in km

# %%
station_names, starttime, inv = INSN.check_stations(Year, Month, Day, Hour, Minute, Second)
# Out:
# data is available for these stations:['DSB', 'IDGL', 'IGLA', 'ILTH', 'IWEX', 'VAL']

# %%
# Sort stations by distance from the event:
station_names, R_hypos = INSN.sort_stations(station_names, starttime, inv, lat, lon, depth)
# Out:
# ['ILTH' 'DSB' 'IWEX' 'IDGL' 'IGLA' 'VAL']

# %%
# Chose the length of the seimograms, in seconds:
length = 195
# Chose how many seconds of data you want to plot before the event time:
pretime = 15
# Lets plot seismograms:
INSN.plot(station_names, starttime, length, pretime, R_hypos)
# Out:
# <img src="data:image/png;base64,..." width="599.5">
